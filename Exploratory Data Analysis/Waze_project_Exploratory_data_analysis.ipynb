# %% [markdown]
# <a href="https://colab.research.google.com/github/deedee-ke/Data-Science-Project-Portolio/blob/main/Waze_project_Exploratory_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Waze Project**
# **Exploratory Data analysis**

# %% [markdown]
# # **Visualize a story in Python**

# %% [markdown]
# ### **Task 1. Imports and data loading**
#
# For EDA of the data, import the data and packages that will be most helpful, such as pandas, numpy, and matplotlib.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Load the dataset into a dataframe
df = pd.read_csv('/content/sample_data/waze_dataset.csv')

# %% [markdown]
# ### **Task 2. Data exploration and cleaning**

# %% [markdown]
# #### **Data overview and summary statistics**

# %%
df.head(10)
# Out:
#    ID     label  sessions  drives  total_sessions  n_days_after_onboarding  \
# 0   0  retained       283     226      296.748273                     2276
# 1   1  retained       133     107      326.896596                     1225
# 2   2  retained       114      95      135.522926                     2651
# 3   3  retained        49      40       67.589221                       15
# 4   4  retained        84      68      168.247020                     1562
# 5   5  retained       113     103      279.544437                     2637
# 6   6  retained         3       2      236.725314                      360
# 7   7  retained        39      35      176.072845                     2999
# 8   8  retained        57      46      183.532018                      424
# 9   9   churned        84      68      244.802115                     2997
#
#    total_navigations_fav1  total_navigations_fav2  driven_km_drives  \
# 0                     208                       0       2628.845068
# ...

# %%
df.size
# Out:
# 194987

# %%
df.describe().T
# Out:
#                            count         mean          std        min  \
# ID                       14999.0  7499.000000  4329.982679   0.000000
# sessions                 14999.0    80.633776    80.699065   0.000000
# drives                   14999.0    67.281152    65.913872   0.000000
# total_sessions           14999.0   189.964447   136.405128   0.220211
# n_days_after_onboarding  14999.0  1749.837789  1008.513876   4.000000
# total_navigations_fav1   14999.0   121.605974   148.121544   0.000000
# total_navigations_fav2   14999.0    29.672512    45.394651   0.000000
# driven_km_drives         14999.0  4039.340921  2502.149334  60.441250
# duration_minutes_drives  14999.0  1860.976012  1446.702288  18.282082
# activity_days            14999.0    15.537102     9.004655   0.000000
# driving_days             14999.0    12.179879     7.824036   0.000000
#
#                                  25%          50%           75%           max
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       14999 non-null  int64
#  1   label                    14299 non-null  object
#  2   sessions                 14999 non-null  int64
#  3   drives                   14999 non-null  int64
#  4   total_sessions           14999 non-null  float64
#  5   n_days_after_onboarding  14999 non-null  int64
#  6   total_navigations_fav1   14999 non-null  int64
#  7   total_navigations_fav2   14999 non-null  int64
#  8   driven_km_drives         14999 non-null  float64
#  9   duration_minutes_drives  14999 non-null  float64
#  10  activity_days            14999 non-null  int64
#  11  driving_days             14999 non-null  int64
#  12  device                   14999 non-null  object
# dtypes: float64(3), int64(8), object(2)
# memory usage: 1.5+ MB

# %% [markdown]
# ### **Task 3a. Visualizations**

# %% [markdown]
# #### **`sessions`**
#
# _The number of occurrences of a user opening the app during the month_

# %%
def create_boxplot(data, x_column):
    plt.figure(figsize=(5, 1))
    sns.boxplot(x=data[x_column], fliersize=1)
    plt.title(f'{x_column} box plot')
    plt.show()

# %%
create_boxplot(df, 'driven_km_drives')

# %%
# Box plot
plt.figure(figsize=(5,1))
sns.boxplot(x=df['sessions'], fliersize=1)
plt.title('sessions box plot')
# Out:
# Text(0.5, 1.0, 'sessions box plot')

# %%
def create_histogram_with_median(data, x_column):
    plt.figure(figsize=(5, 3))
    sns.histplot(x=data[x_column])
    median = data[x_column].median()
    plt.axvline(median, color='red', linestyle='--')
    plt.text(0.75 * median, plt.ylim()[1] * 0.9, f'median={median}', color='red')
    plt.title(f'{x_column} histogram')
    plt.show()

# %%
create_histogram_with_median(df, 'sessions')

# %% [markdown]
# The `sessions` variable is a right-skewed distribution with half of the observations having 56 or fewer sessions. However, as indicated by the boxplot, some users have more than 700.

# %% [markdown]
# #### **`drives`**
#
# _An occurrence of driving at least 1 km during the month_

# %%
create_boxplot(df, 'drives')

# %%
create_histogram_with_median(df, 'drives')

# %% [markdown]
# The `drives` information follows a distribution similar to the `sessions` variable. It is right-skewed, approximately log-normal, with a median of 48. However, some drivers had over 400 drives in the last month.

# %% [markdown]
# #### **`total_sessions`**
#
# _A model estimate of the total number of sessions since a user has onboarded_

# %%
create_boxplot(df, 'total_sessions')

# %%
create_histogram_with_median(df, 'total_sessions')

# %% [markdown]
# The `total_sessions` is a right-skewed distribution. The median total number of sessions is 159.6. This is interesting information because, if the median number of sessions in the last month was 56 and the median total sessions was ~160, then it seems that a large proportion of a user's (estimated) total drives might have taken place in the last month.

# %% [markdown]
# #### **`n_days_after_onboarding`**
#
# _The number of days since a user signed up for the app_

# %%
create_boxplot(df, 'n_days_after_onboarding')

# %%
create_histogram_with_median(df, 'n_days_after_onboarding')

# %% [markdown]
# The total user tenure (i.e., number of days since
# onboarding) is a uniform distribution with values ranging from near-zero to \~3,500 (\~9.5 years).

# %% [markdown]
# #### **`driven_km_drives`**
#
# _Total kilometers driven during the month_

# %%
create_boxplot(df, 'driven_km_drives')

# %%
create_histogram_with_median(df, 'driven_km_drives')

# %% [markdown]
# The number of drives driven in the last month per user is a right-skewed distribution with half the users driving under 3,495 kilometers.

# %% [markdown]
# #### **`duration_minutes_drives`**
#
# _Total duration driven in minutes during the month_

# %%
create_boxplot(df, 'duration_minutes_drives')

# %%
create_histogram_with_median(df, 'duration_minutes_drives')

# %% [markdown]
# The `duration_minutes_drives` variable has a heavily skewed right tail. Half of the users drove less than \~1,478 minutes (\~25 hours), but some users clocked over 250 hours over the month.

# %% [markdown]
# #### **`activity_days`**
#
# _Number of days the user opens the app during the month_

# %%
create_boxplot(df, 'activity_days')

# %%
create_histogram_with_median(df, 'activity_days')

# %% [markdown]
# Within the last month, users opened the app a median of 16 times. The box plot reveals a centered distribution. The histogram shows a nearly uniform distribution of ~500 people opening the app on each count of days. However, there are ~250 people who didn't open the app at all and ~250 people who opened the app every day of the month.
#
# This distribution is noteworthy because it does not mirror the `sessions` distribution, which you might think would be closely correlated with `activity_days`.

# %% [markdown]
# #### **`driving_days`**
#
# _Number of days the user drives (at least 1 km) during the month_

# %%
create_boxplot(df, 'driving_days')

# %%
create_histogram_with_median(df, 'driving_days')

# %% [markdown]
# The number of days users drove each month is almost uniform, and it largely correlates with the number of days they opened the app that month, except the `driving_days` distribution tails off on the right.
#
# However, there were almost twice as many users (\~1,000 vs. \~550) who did not drive at all during the month. This might seem counterintuitive when considered together with the information from `activity_days`. That variable had \~500 users opening the app on each of most of the day counts, but there were only \~250 users who did not open the app at all during the month and ~250 users who opened the app every day. Flag this for further investigation later.

# %% [markdown]
# #### **`device`**
#
# _The type of device a user starts a session with_

# %%
def visualize_categorical_distribution(data, column):
    plt.figure(figsize=(8, 5))
    column_counts = data[column].value_counts(normalize=True) * 100
    sns.barplot(x=column_counts.values, y=column_counts.index, palette='viridis')

    for i, value in enumerate(column_counts.values):
        plt.text(value, i, f'{value:.2f}%', va='center')

    plt.title(f'Distribution of {column}')
    plt.xlabel('Percentage')
    plt.ylabel(column)
    plt.show()

# %%
visualize_categorical_distribution(df, 'device')

# %% [markdown]
# There are nearly twice as many iPhone users as Android users represented in this data.

# %% [markdown]
# #### **`label`**
#
# _Binary target variable (“retained” vs “churned”) for if a user has churned anytime during the course of the month_
#
# This is also a categorical variable, and as such would not be plotted as a box plot. Plot a pie chart instead.

# %%
visualize_categorical_distribution(df, 'label')

# %% [markdown]
# Less than 18% of the users churned.

# %% [markdown]
# #### **`driving_days` vs. `activity_days`**
#
# Because both `driving_days` and `activity_days` represent counts of days over a month and they're also closely related, you can plot them together on a single histogram. This will help to better understand how they relate to each other without having to scroll back and forth comparing histograms in two different places.
#
# Plot a histogram that, for each day, has a bar representing the counts of `driving_days` and `user_days`.

# %%
# Combine 'driving_days' and 'activity_days' into a single DataFrame for easier plotting
combined_df = pd.melt(df[['driving_days', 'activity_days']], var_name='activity')

plt.figure(figsize=(10, 6))
sns.histplot(data=combined_df, x='value', hue='activity', bins=range(0, 33), multiple='stack')
plt.xlabel('Days')
plt.ylabel('Count')
plt.title('Comparison of Driving Days and Activity Days')

# Adding a legend
plt.legend(title='Activity', labels=['Driving Days', 'Activity Days'])

plt.show()

# %%
print(df['driving_days'].max())
print(df['activity_days'].max())
# Out:
# 30
# 31

# %%
# Scatter plot
sns.scatterplot(data=df, x='driving_days', y='activity_days')
plt.title('driving_days vs. activity_days')
plt.plot([0,31], [0,31], color='red', linestyle='--');

# %% [markdown]
# #### **Retention by device**
#
# Plot a histogram that has four bars&mdash;one for each device-label combination&mdash;to show how many iPhone users were retained/churned and how many Android users were retained/churned.

# %%
# Histogram
plt.figure(figsize=(5,4))
sns.histplot(data=df,
             x='device',
             hue='label',
             multiple='dodge',
             shrink=0.9
             )
plt.title('Retention by device histogram');

# %% [markdown]
# The proportion of churned users to retained users is consistent between device types.

# %% [markdown]
# #### **Retention by kilometers driven per driving day**

# %%
# 1. Create `km_per_driving_day` column
df['km_per_driving_day'] = df['driven_km_drives'] / df['driving_days']

# 2. Call `describe()` on the new column
df['km_per_driving_day'].describe()
# Out:
# count    1.499900e+04
# mean              inf
# std               NaN
# min      3.022063e+00
# 25%      1.672804e+02
# 50%      3.231459e+02
# 75%      7.579257e+02
# max               inf
# Name: km_per_driving_day, dtype: float64

# %%
# 1. Convert infinite values to zero
df.loc[df['km_per_driving_day']==np.inf, 'km_per_driving_day'] = 0

# 2. Confirm that it worked
df['km_per_driving_day'].describe()
# Out:
# count    14999.000000
# mean       578.963113
# std       1030.094384
# min          0.000000
# 25%        136.238895
# 50%        272.889272
# 75%        558.686918
# max      15420.234110
# Name: km_per_driving_day, dtype: float64

# %%
# Histogram
plt.figure(figsize=(12,5))
sns.histplot(data=df,
             x='km_per_driving_day',
             bins=range(0,1201,20),
             hue='label',
             multiple='fill')
plt.ylabel('%', rotation=0)
plt.title('Churn rate by mean km per driving day');

# %% [markdown]
# The churn rate tends to increase as the mean daily distance driven increases, confirming what was found in the previous course. It would be worth investigating further the reasons for long-distance users to discontinue using the app.

# %% [markdown]
# #### **Churn rate per number of driving days**
#
# Create another histogram just like the previous one, only this time it should represent the churn rate for each number of driving days.

# %%
# Histogram
plt.figure(figsize=(12,5))
sns.histplot(data=df,
             x='driving_days',
             bins=range(1,32),
             hue='label',
             multiple='fill',
             discrete=True)
plt.ylabel('%', rotation=0)
plt.title('Churn rate per driving day');

# %% [markdown]
# The churn rate is highest for people who didn't use Waze much during the last month. The more times they used the app, the less likely they were to churn. While 40% of the users who didn't use the app at all last month churned, nobody who used the app 30 days churned.
#
# This isn't surprising. If people who used the app a lot churned, it would likely indicate dissatisfaction. When people who don't use the app churn, it might be the result of dissatisfaction in the past, or it might be indicative of a lesser need for a navigational app. Maybe they moved to a city with good public transportation and don't need to drive anymore.

# %% [markdown]
# #### **Proportion of sessions that occurred in the last month**

# %%
df['percent_sessions_in_last_month'] = df['sessions'] / df['total_sessions']

# %%
df['percent_sessions_in_last_month'].median()
# Out:
# 0.42309702992763176

# %%
create_histogram_with_median(df, 'percent_sessions_in_last_month')

# %%
df['n_days_after_onboarding'].median()
# Out:
# 1741.0

# %% [markdown]
# Half of the people in the dataset had 40% or more of their sessions in just the last month, yet the overall median time since onboarding is almost five years.

# %%
# Histogram
data = df.loc[df['percent_sessions_in_last_month']>=0.4]
plt.figure(figsize=(5,3))
sns.histplot(x=data['n_days_after_onboarding'])
plt.title('Num. days after onboarding for users with >=40% sessions in last month');

# %% [markdown]
# The number of days since onboarding for users with 40% or more of their total sessions occurring in just the last month is a uniform distribution. This is very strange. It's worth asking Waze why so many long-time users suddenly used the app so much in the last month.

# %% [markdown]
# ### **Task 3b. Handling outliers**

# %%
def outlier_imputer(column_name, percentile):
    # Calculate threshold
    threshold = df[column_name].quantile(percentile)
    # Impute threshold for values > than threshold
    df.loc[df[column_name] > threshold, column_name] = threshold

    print('{:>25} | percentile: {} | threshold: {}'.format(column_name, percentile, threshold))

# %%
for column in ['sessions', 'drives', 'total_sessions',
               'driven_km_drives', 'duration_minutes_drives']:
               outlier_imputer(column, 0.95)
# Out:
#                  sessions | percentile: 0.95 | threshold: 243.0
#                    drives | percentile: 0.95 | threshold: 201.0
#            total_sessions | percentile: 0.95 | threshold: 454.3632037399997
#          driven_km_drives | percentile: 0.95 | threshold: 8889.7942356
#   duration_minutes_drives | percentile: 0.95 | threshold: 4668.899348999998

# %%
df.describe().T
# Out:
#                                   count         mean          std        min  \
# ID                              14999.0  7499.000000  4329.982679   0.000000
# sessions                        14999.0    76.568705    67.297958   0.000000
# drives                          14999.0    64.058204    55.306924   0.000000
# total_sessions                  14999.0   184.031320   118.600463   0.220211
# n_days_after_onboarding         14999.0  1749.837789  1008.513876   4.000000
# total_navigations_fav1          14999.0   121.605974   148.121544   0.000000
# total_navigations_fav2          14999.0    29.672512    45.394651   0.000000
# driven_km_drives                14999.0  3939.632764  2216.041510  60.441250
# duration_minutes_drives         14999.0  1789.647426  1222.705167  18.282082
# activity_days                   14999.0    15.537102     9.004655   0.000000
# driving_days                    14999.0    12.179879     7.824036   0.000000
# ...

# %% [markdown]
# ### **Task 4 Conclusion**
#
# Upon thorough data exploration and visualization, the next crucial step involves sharing insights with Harriet Hadzic, Waze's Director of Data Analysis, focusing on key findings pertinent to the user churn project.
#
# **Key Points to Address:**
#
# 1. **Distribution Analysis:** Most variables exhibited either a right-skewed or uniform distribution. This signifies that for right-skewed distributions, the majority of users had lower-end values for that variable. For uniform distributions, users were equally likely to have values anywhere within the variable's range.
#
# 2. **Data Quality Considerations:** Although most data appeared reliable, certain variables displayed highly improbable or potentially erroneous outliers, like 'driven_km_drives.' Additionally, discrepancies between monthly variables such as 'activity_days' and 'driving_days' suggest potential data collection inconsistencies across months.
#
# 3. **Follow-up Queries:** I intend to inquire with the Waze data team about the consistency of monthly variable collection to clarify the disparate maximum values observed. Additionally, I aim to understand any significant changes or updates in the last month that might have triggered increased app usage among long-term users.
#
# 4. **User Churn Metrics:** The dataset indicates less than 18% churn rate and approximately 82% user retention.
#
# 5. **Correlation with User Churn:** Notably, distance driven per driving day positively correlated with user churn, indicating that users driving longer distances were more likely to churn. Conversely, the number of driving days exhibited a negative correlation with churn, suggesting that users who drove more frequently were less likely to churn.
#
# 6. **Representation Across User Tenure:** Users across various tenures, from new users to those with approximately 10 years of tenure, were evenly represented in the dataset. The histogram for 'n_days_after_onboarding' demonstrated a uniform distribution, indicating balanced representation across user tenures.
#
# These insights lay the groundwork for a comprehensive understanding of user behavior and potential churn factors, providing a solid foundation for further analysis and strategic decision-making within the Waze team.
